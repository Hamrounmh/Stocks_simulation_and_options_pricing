# %%
=
# Out:
#   File "<ipython-input-1-c61908080f91>", line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# https://github.com/RomelTorres/alpha_vantage

# %% [markdown]
# https://www.alphavantage.co/documentation/

# %% [markdown]
# ### Example of stock picking ratio based on fundamental data

# %% [markdown]
# #### price-to-book

# %% [markdown]
# The price-to-book ratio or P/B ratio measures whether a stock is over or undervalued by comparing the net value (assets - liabilities) of a company to its market capitalization
# If the ratio is above 10, the stock is expected to double in value.
# If the ratio is above 15, the stock is expected to triple in value.
# If the ratio is above 20, the stock is expected to quadruple in value.

# %% [markdown]
# #### P/E ratio

# %% [markdown]
# The P/E ratio is important because it provides a measuring stick for comparing whether a stock is overvalued or undervalued. A high P/E ratio could mean that a stock's price is expensive relative to earnings and possibly overvalued. Conversely, a low P/E ratio might indicate that the current stock price is cheap relative to earnings.

# %% [markdown]
# #### Profit Margin

# %% [markdown]
# Profit Margin = Net Income / Sales Revenue
# According to Warren Buffet, this is the best way to calculate the value of a company. Warren Buffet’s stock investment strategy uses these financial ratios to pick stocks with growth potential.
# Stock investors should look back at least five years to gauge if the profit margins are in an ascending trend.

# %% [markdown]
# ### Example of stock picking ratio based on Technical Analysis

# %% [markdown]
# #### Moving Averages

# %% [markdown]
# As a general guideline, if the price is above a moving average, the trend is up. If the price is below a moving average, the trend is down. However, moving averages can have different lengths (discussed shortly), so one MA may indicate an uptrend while another MA indicates a downtrend.

# %% [markdown]
# #### Relative strength indicator (RSI)

# %% [markdown]
# The relative strength index (RSI) is a momentum indicator used in technical analysis that measures the magnitude of recent price changes to evaluate overbought or oversold conditions in the price of a stock or other asset. The RSI is displayed as an oscillator (a line graph that moves between two extremes) and can have a reading from 0 to 100.

# %% [markdown]
# #### Momentum

# %% [markdown]
# traditional interpretation and usage of the RSI are that values of 70 or above indicate that a security is becoming overbought or overvalued and may be primed for a trend reversal or corrective pullback in price. An RSI reading of 30 or below indicates an oversold or undervalued condition.

# %% [markdown]
# ## Getting data

# %%
import time
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from alpha_vantage.timeseries import TimeSeries
#ts = TimeSeries(key='IWVCPPHPKILWRYGB', output_format='pandas')
ApiKeys=['AQVJIO3GPF7847J3','QOQ2HW0Z174Z3QEJ']

ts = TimeSeries(key='AQVJIO3GPF7847J3', output_format='pandas')

# %%
#portfolio_composition = [('MSFT',0.3),('AAPL',0.2),('GOOG',0.3),('FB',0.2)]

stocks = ['XEL','AMD','PFE','NVDA','QCOM','SUMO','VST','TUFN','MSFT','TSLA']
initial_weight = np.array([0.00222,0.00248,0.47979,0.19947,0.00098,0.07991,0.23616,0.00024,0.00069,0.00024])
returns = pd.DataFrame({})
i = 1 
for s in stocks: #portfolio_composition:
    if i==6:
        time.sleep(120)
    data, meta_data = ts.get_daily_adjusted(symbol=s)
    data['return_%s' % (s)] = data['4. close'].pct_change(1)
    returns = returns.join(data[['return_%s' % (s)]],how="outer").dropna()
    i=i+1
    
returns
# Out:
#             return_XEL  return_AMD  return_PFE  return_NVDA  return_QCOM  \
# date
# 2020-10-27    0.029462    0.032461    0.055853     0.060961     0.035614
# 2020-10-28   -0.006785   -0.020764    0.004819    -0.030482    -0.038437
# 2020-10-29    0.010139    0.036260   -0.005637     0.039094     0.024968
# 2020-10-30   -0.024380    0.007898   -0.020701    -0.003716    -0.004921
# 2020-11-02   -0.016443   -0.024549    0.001105    -0.033699    -0.011798
# ...                ...         ...         ...          ...          ...
# 2021-03-15   -0.005362   -0.003021   -0.011722    -0.007524    -0.015039
# 2021-03-16    0.011485    0.001452    0.001118    -0.003748    -0.002016
# 2021-03-17    0.004647    0.057732    0.000559     0.048634     0.032139
# 2021-03-18   -0.009367   -0.011890    0.006755    -0.009595    -0.009693
# 2021-03-19   -0.011922   -0.015442   -0.013056    -0.025822    -0.022895
#
#             return_SUMO  return_VST  return_TUFN  return_MSFT  return_TSLA
# date
# 2020-10-27     0.055252    0.062824     0.070093     0.052151     0.045958
# 2020-10-28     0.020089    0.000577    -0.051699    -0.009965    -0.011708
# 2020-10-29     0.037037   -0.001727     0.051242     0.011113     0.058731
# 2020-10-30    -0.025930   -0.020857    -0.009231     0.000692    -0.031135
# 2020-11-02    -0.077003   -0.035345    -0.042710    -0.019861    -0.055178
# ...                 ...         ...          ...          ...          ...
# 2021-03-15     0.055742    0.025938     0.049837    -0.012200     0.045887
# 2021-03-16    -0.009048    0.048005     0.004926     0.002827    -0.035522
# 2021-03-17     0.018923    0.029780     0.091398     0.027393     0.074484
# 2021-03-18     0.043544   -0.029480    -0.002681     0.001606    -0.002611
# 2021-03-19     0.008167    0.035928    -0.020997    -0.023899    -0.022582
#
# [99 rows x 10 columns]

# %%
returns.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Compute mean returns

# %%
daily_returns_portfolio_mean = returns.mean()
daily_returns_portfolio_mean
# Out:
# return_XEL     0.001380
# return_AMD     0.000173
# return_PFE     0.000542
# return_NVDA    0.000579
# return_QCOM   -0.000270
# return_SUMO    0.001466
# return_VST     0.001737
# return_TUFN   -0.003947
# return_MSFT   -0.000892
# return_TSLA   -0.003656
# dtype: float64

# %% [markdown]
# We can then compute the total portfolio return by simply using

# %%
allocated_daily_returns = (initial_weight * daily_returns_portfolio_mean)
portfolio_return = np.sum(allocated_daily_returns)
portfolio_return
# Out:
# 0.0009037083319514167

# %% [markdown]
# My average portfolio return is -0.1%

# %% [markdown]
# My cumulative return for each stock

# %%
Cumulative_returns_daily = (1+returns).cumprod() -1
Cumulative_returns_daily
# Out:
#             return_XEL  return_AMD  return_PFE  return_NVDA  return_QCOM  \
# date
# 2020-10-27    0.029462    0.032461    0.055853     0.060961     0.035614
# 2020-10-28    0.022477    0.011023    0.060941     0.028620    -0.004192
# 2020-10-29    0.032843    0.047682    0.054961     0.068833     0.020671
# 2020-10-30    0.007662    0.055957    0.033122     0.064861     0.015649
# 2020-11-02   -0.008907    0.030034    0.034264     0.028976     0.003667
# ...                ...         ...         ...          ...          ...
# 2021-03-15    0.140672   -0.046767    0.044655     0.007938    -0.057912
# 2021-03-16    0.153773   -0.045383    0.045823     0.004160    -0.059812
# 2021-03-17    0.159135    0.009729    0.046408     0.052997    -0.029595
# 2021-03-18    0.148278   -0.002277    0.053476     0.042894    -0.039002
# 2021-03-19    0.134588   -0.017684    0.039722     0.015964    -0.061004
#
#             return_SUMO  return_VST  return_TUFN  return_MSFT  return_TSLA
# date
# 2020-10-27     0.055252    0.062824     0.070093     0.052151     0.045958
# 2020-10-28     0.076451    0.063437     0.014771     0.041667     0.033712
# 2020-10-29     0.116319    0.061600     0.066770     0.053242     0.094423
# 2020-10-30     0.087373    0.039459     0.056923     0.053971     0.060348
# 2020-11-02     0.003642    0.002719     0.011782     0.033038     0.001840
# ...                 ...         ...          ...          ...          ...
# 2021-03-15    -0.073042    0.017660    -0.438725    -0.102898    -0.372592
# 2021-03-16    -0.081429    0.066512    -0.435961    -0.100363    -0.394879
# 2021-03-17    -0.064047    0.098273    -0.384409    -0.075719    -0.349807
# 2021-03-18    -0.023291    0.065896    -0.386059    -0.074235    -0.351505
# 2021-03-19    -0.015314    0.104192    -0.398950    -0.096360    -0.366149
#
# [99 rows x 10 columns]

# %%
Cumulative_returns_daily.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Daily portfolio portfolio return

# %%
portfolio_daily_returns = returns.dot(initial_weight)
portfolio_daily_returns
# Out:
# date
# 2020-10-27    0.058454
# 2020-10-28   -0.002153
# 2020-10-29    0.007816
# 2020-10-30   -0.017720
# 2020-11-02   -0.020838
#                 ...
# 2021-03-15    0.003435
# 2021-03-16    0.010424
# 2021-03-17    0.018758
# 2021-03-18   -0.002215
# 2021-03-19   -0.002391
# Length: 99, dtype: float64

# %%
portfolio_daily_returns.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Comulative portfolio portfolio return

# %%
Cumulative_portfolio_returns_daily = (1+portfolio_daily_returns).cumprod()-1
Cumulative_portfolio_returns_daily
# Out:
# date
# 2020-10-27    0.058454
# 2020-10-28    0.056175
# 2020-10-29    0.064430
# 2020-10-30    0.045569
# 2020-11-02    0.023781
#                 ...
# 2021-03-15    0.055234
# 2021-03-16    0.066233
# 2021-03-17    0.086234
# 2021-03-18    0.083828
# 2021-03-19    0.081236
# Length: 99, dtype: float64

# %%
Cumulative_portfolio_returns_daily.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Benchmark = S&P500 Code = SPY

# %%
data, meta_data = ts.get_daily_adjusted(symbol='SPY')
spy_return = data['4. close'].pct_change(1)

# %%
import numpy as np
x = range(len(portfolio_daily_returns))
pr = portfolio_daily_returns
#plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(x,pr,label="Portfolio")
plt.plot(range(len(spy_return)),spy_return,label=" SP500")

plt.xlabel("Day")
plt.ylabel("Portfolio return")

plt.grid()
plt.legend()

plt.show()

# %%
spy_cum = (1+spy_return).cumprod()-1
prc =  (1+portfolio_daily_returns).cumprod()-1
x = range(len(portfolio_daily_returns))
#plt.rcParams['figure.figsize'] = [10, 10]

plt.plot(x,prc,label="Portfolio")
plt.plot(range(len(spy_cum)),spy_cum,label=" SP500")

plt.xlabel("Day")
plt.ylabel("Portfolio return")

plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ### Sharpe Ratio

# %%
Sharpe_Ratio = portfolio_return / portfolio_daily_returns.std()
Sharpe_Ratio
# Out:
# 0.058929609041145456

# %% [markdown]
# ### How to extract Currency rate

# %%
from alpha_vantage.foreignexchange import ForeignExchange
cc = ForeignExchange(key='IWVCPPHPKILWRYGB',output_format='pandas')
# There is no metadata in this call
data, meta_data = cc.get_currency_exchange_intraday('EUR', 'USD', '60min', 'full')
EurUsd_change = data['4. close'].pct_change(1)
EurUsd_change.plot()

plt.title('Daily close value for usd ')
plt.grid()
plt.show()

# %% [markdown]
# ### Getting cryptocurrencies data

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib.pyplot as plt

cc = CryptoCurrencies(key='IWVCPPHPKILWRYGB', output_format='pandas')
data, meta_data =    cc.get_currency_exchange_intraday('EUR', 'USD', '5min', 'full')
#data, meta_data = cc.get_digital_currency_daily(symbol='BTC', market='CNY')
data['4b. close (USD)'].plot()
plt.tight_layout()
plt.title('Daily close value for bitcoin (BTC)')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-8685dc472abf> in <module>
#       3
#       4 cc = CryptoCurrencies(key='IWVCPPHPKILWRYGB', output_format='pandas')
# ----> 5 data, meta_data =    cc.get_currency_exchange_intraday('EUR', 'USD', '5min', 'full')
#       6 #data, meta_data = cc.get_digital_currency_daily(symbol='BTC', market='CNY')
#       7 data['4b. close (USD)'].plot()
#
# AttributeError: 'CryptoCurrencies' object has no attribute 'get_currency_exchange_intraday'
